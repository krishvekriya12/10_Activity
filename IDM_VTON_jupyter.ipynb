# %% [markdown]
# <a href="https://colab.research.google.com/github/krishvekriya12/10_Activity/blob/main/IDM_VTON_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/IDM-VTON-hf
# %cd /content/IDM-VTON-hf

# !apt -y install -qq aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/IDM-VTON/resolve/main/densepose/model_final_162be9.pkl -d /content/IDM-VTON-hf/ckpt/densepose -o model_final_162be9.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/IDM-VTON/resolve/main/humanparsing/parsing_atr.onnx -d /content/IDM-VTON-hf/ckpt/humanparsing -o parsing_atr.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/IDM-VTON/resolve/main/humanparsing/parsing_lip.onnx -d /content/IDM-VTON-hf/ckpt/humanparsing -o parsing_lip.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/IDM-VTON/resolve/main/openpose/ckpts/body_pose_model.pth -d /content/IDM-VTON-hf/ckpt/openpose/ckpts -o body_pose_model.pth

# !pip install -q diffusers==0.25.0 accelerate==0.26.1 einops==0.7.0 onnxruntime==1.16.2 cloudpickle omegaconf gradio==4.24.0 fvcore av config

# %cd /content/IDM-VTON-hf
# !python app.py
# Out:
# /content
# fatal: destination path 'IDM-VTON-hf' already exists and is not an empty directory.
# /content/IDM-VTON-hf
# aria2 is already the newest version (1.36.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 6f564b|OK  |       0B/s|/content/IDM-VTON-hf/ckpt/densepose/model_final_162be9.pkl
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9b7390|OK  |       0B/s|/content/IDM-VTON-hf/ckpt/humanparsing/parsing_atr.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 156fef|OK  |       0B/s|/content/IDM-VTON-hf/ckpt/humanparsing/parsing_lip.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# fee33f|OK  |       0B/s|/content/IDM-VTON-hf/ckpt/openpose/ckpts/body_pose_model.pth
#
# Status Legend:
# (OK):download completed.
# ERROR: Could not find a version that satisfies the requirement onnxruntime==1.16.2 (from versions: 1.17.0, 1.17.1, 1.17.3, 1.18.0, 1.18.1, 1.19.0, 1.19.2, 1.20.0, 1.20.1, 1.21.0, 1.21.1, 1.22.0, 1.22.1, 1.23.0, 1.23.1, 1.23.2, 1.24.0.dev20251031003, 1.24.1, 1.24.2, 1.24.3, 1.24.4)
# ERROR: No matching distribution found for onnxruntime==1.16.2
# /content/IDM-VTON-hf
# Traceback (most recent call last):
#   File "/content/IDM-VTON-hf/app.py", line 3, in <module>
#     from src.tryon_pipeline import StableDiffusionXLInpaintPipeline as TryonPipeline
#   File "/content/IDM-VTON-hf/src/tryon_pipeline.py", line 29, in <module>
#     from diffusers.image_processor import PipelineImageInput, VaeImageProcessor
#   File "/usr/local/lib/python3.12/dist-packages/diffusers/__init__.py", line 5, in <module>
#     from .utils import (
#   File "/usr/local/lib/python3.12/dist-packages/diffusers/utils/__init__.py", line 37, in <module>
#     from .dynamic_modules_utils import get_class_from_dynamic_module
#   File "/usr/local/lib/python3.12/dist-packages/diffusers/utils/dynamic_modules_utils.py", line 28, in <module>
#     from huggingface_hub import cached_download, hf_hub_download, model_info
# ImportError: cannot import name 'cached_download' from 'huggingface_hub' (/usr/local/lib/python3.12/dist-packages/huggingface_hub/__init__.py). Did you mean: 'hf_hub_download'?
